# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb

df=pd.read_csv("calories_data.csv")
df
# Out:
#         User_ID  Gender   Age  Height  Weight  Duration  Heart_Rate  \
# 0      14733363    male  68.0   190.0     NaN      29.0       105.0
# 1      14861698  female  20.0   166.0    60.0      14.0        94.0
# 2      11179863    male  69.0   179.0    79.0       5.0        88.0
# 3      16180408  female  34.0   179.0    71.0      13.0       100.0
# 4      17771927  female  27.0   154.0    58.0      10.0        81.0
# ...         ...     ...   ...     ...     ...       ...         ...
# 14995  15644082  female  20.0   193.0    86.0      11.0        92.0
# 14996  17212577  female  27.0   165.0    65.0       6.0        85.0
# 14997  17271188  female  43.0   159.0    58.0      16.0        90.0
# 14998  18643037    male  78.0   193.0    97.0       2.0        84.0
# 14999  11751526    male  63.0   173.0    79.0      18.0        92.0
#
#        Body_Temp  Calories
# 0           40.8     231.0
# 1           40.3      66.0
# 2           38.7      26.0
# 3           40.5      71.0
# ...

# %%
df.head()
# Out:
#     User_ID  Gender   Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male  68.0   190.0     NaN      29.0       105.0       40.8
# 1  14861698  female  20.0   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male  69.0   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female  34.0   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female  27.0   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
df.tail()
# Out:
#         User_ID  Gender   Age  Height  Weight  Duration  Heart_Rate  \
# 14995  15644082  female  20.0   193.0    86.0      11.0        92.0
# 14996  17212577  female  27.0   165.0    65.0       6.0        85.0
# 14997  17271188  female  43.0   159.0    58.0      16.0        90.0
# 14998  18643037    male  78.0   193.0    97.0       2.0        84.0
# 14999  11751526    male  63.0   173.0    79.0      18.0        92.0
#
#        Body_Temp  Calories
# 14995       40.4      45.0
# 14996       39.2      23.0
# 14997       40.1      75.0
# 14998       38.3      11.0
# 14999       40.5      98.0

# %%
df.shape
# Out:
# (15000, 9)

# %%
df.columns
# Out:
# Index(['User_ID', 'Gender', 'Age', 'Height', 'Weight', 'Duration',
#        'Heart_Rate', 'Body_Temp', 'Calories'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         14979 non-null  float64
#  3   Height      15000 non-null  float64
#  4   Weight      14986 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  14979.000000  15000.000000  14986.000000  15000.000000
# mean   1.497736e+07     42.774952    174.465133     74.964500     15.530600
# std    2.872851e+06     16.974281     14.258114     15.037271      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %%
df.dtypes
# Out:
# User_ID         int64
# Gender         object
# Age           float64
# Height        float64
# Weight        float64
# Duration      float64
# Heart_Rate    float64
# Body_Temp     float64
# Calories      float64
# dtype: object

# %%
df.isna().sum()
# Out:
# User_ID        0
# Gender         0
# Age           21
# Height         0
# Weight        14
# Duration       0
# Heart_Rate     0
# Body_Temp      0
# Calories       0
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array([68., 20., 69., 34., 27., 36., 33., 41., 60., 26., 21., nan, 32.,
#        53., 39., 46., 50., 67., 31., 48., 29., 42., 62., 38., 25., 24.,
#        22., 74., 70., 44., 61., 63., 54., 35., 28., 77., 64., 45., 66.,
#        57., 49., 47., 40., 55., 23., 43., 52., 79., 51., 59., 30., 37.,
#        56., 78., 58., 73., 65., 71., 75., 72., 76.])

# %%
df['Weight'].unique()
# Out:
# array([ nan,  60.,  79.,  71.,  58.,  50.,  56.,  85.,  94.,  51.,  76.,
#         54.,  62.,  82.,  67.,  65.,  86.,  93.,  59.,  75.,  73.,  88.,
#         68.,  84.,  80.,  57.,  70.,  66.,  55.,  98.,  69., 101.,  89.,
#         64.,  63.,  77.,  61.,  83.,  92.,  72., 100.,  91.,  74.,  87.,
#        107.,  53.,  96.,  81.,  90.,  45.,  52.,  49.,  78.,  47.,  95.,
#        109., 104., 102., 103., 105., 112.,  97.,  99., 111.,  42., 115.,
#         38.,  46., 108., 106.,  48.,  40.,  44., 114.,  41., 110.,  43.,
#        118., 113., 124., 117., 122., 120., 116., 121., 132.,  39., 119.,
#         36., 128., 126., 123.])

# %%
df['Age']=df['Age'].fillna(df['Age'].median())
df['Weight']=df['Weight'].fillna(df['Age'].mean())
df.isna().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %%
df.drop(['User_ID'],axis=1,inplace=True)
df
# Out:
#        Gender   Age  Height     Weight  Duration  Heart_Rate  Body_Temp  \
# 0        male  68.0   190.0  42.769667      29.0       105.0       40.8
# 1      female  20.0   166.0  60.000000      14.0        94.0       40.3
# 2        male  69.0   179.0  79.000000       5.0        88.0       38.7
# 3      female  34.0   179.0  71.000000      13.0       100.0       40.5
# 4      female  27.0   154.0  58.000000      10.0        81.0       39.8
# ...       ...   ...     ...        ...       ...         ...        ...
# 14995  female  20.0   193.0  86.000000      11.0        92.0       40.4
# 14996  female  27.0   165.0  65.000000       6.0        85.0       39.2
# 14997  female  43.0   159.0  58.000000      16.0        90.0       40.1
# 14998    male  78.0   193.0  97.000000       2.0        84.0       38.3
# 14999    male  63.0   173.0  79.000000      18.0        92.0       40.5
#
#        Calories
# 0         231.0
# 1          66.0
# 2          26.0
# 3          71.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
df['Gender']=lab.fit_transform(df['Gender'])
df
# Out:
#        Gender   Age  Height     Weight  Duration  Heart_Rate  Body_Temp  \
# 0           1  68.0   190.0  42.769667      29.0       105.0       40.8
# 1           0  20.0   166.0  60.000000      14.0        94.0       40.3
# 2           1  69.0   179.0  79.000000       5.0        88.0       38.7
# 3           0  34.0   179.0  71.000000      13.0       100.0       40.5
# 4           0  27.0   154.0  58.000000      10.0        81.0       39.8
# ...       ...   ...     ...        ...       ...         ...        ...
# 14995       0  20.0   193.0  86.000000      11.0        92.0       40.4
# 14996       0  27.0   165.0  65.000000       6.0        85.0       39.2
# 14997       0  43.0   159.0  58.000000      16.0        90.0       40.1
# 14998       1  78.0   193.0  97.000000       2.0        84.0       38.3
# 14999       1  63.0   173.0  79.000000      18.0        92.0       40.5
#
#        Calories
# 0         231.0
# 1          66.0
# 2          26.0
# 3          71.0
# ...

# %%
gender_count=df['Gender'].value_counts()
gender_labels=['Male','Female']

plt.figure(figsize=(8,5)) #8 inch wide, 5 inch ht
plt.pie(gender_count,labels=gender_labels,autopct='%1.1f%%',colors=['pink','coral'])
plt.title("Gender Distribution")
plt.show()

# %%
sb.scatterplot(x='Height',y='Weight',data=df)
plt.show() #shows linear relation

# %%
plt.figure(figsize=(8,6))
sb.barplot(x='Duration',y='Calories',data=df,estimator=np.mean,palette="viridis",hue='Duration')
plt.title("Average Calories Burnt vs Duration (in minutes)")
plt.xlabel("Duration")
plt.ylabel("Average Calories burnt")
plt.xticks(rotation=45) #to improve readability, xlabels rotated
plt.show()

# %%
plt.figure(figsize=(8,6))
sb.scatterplot(x="Duration",y="Body_Temp",data=df,hue="Duration")
plt.xlabel("Duration in mins")
plt.ylabel("Body Temperature")
plt.show()

# %%
df.dtypes
# Out:
# Gender          int32
# Age           float64
# Height        float64
# Weight        float64
# Duration      float64
# Heart_Rate    float64
# Body_Temp     float64
# Calories      float64
# dtype: object

# %%
numeric_cols=df.select_dtypes(include=[np.number]).columns #boxplot can only be done on numeric cols

plt.figure(figsize=(12,8))
sb.boxplot(data=df[numeric_cols])
plt.title("Boxplot of all features")
plt.show()

# %%
#outlier removal

outlier_cols=['Height',"Weight","Heart_Rate","Body_Temp","Calories"]

def rem_outliers(df,columns):
    for col in columns:

        Q1=df[col].quantile(0.25)
        Q3=df[col].quantile(0.75)
        IQR=Q3-Q1

        low=Q1-1.5*IQR
        upp=Q3+1.5*IQR

        df=df[(df[col] >= low) & (df[col]<=upp)]

    return df
df_cleaned=rem_outliers(df,outlier_cols)

# %%
corr_matrix=df_cleaned.corr() #correlation
plt.figure(figsize=(8,6))
sb.heatmap(corr_matrix,annot=True,cmap="coolwarm",fmt=".2f",linewidths=0.5) 
#annot = True => to view values within cells

plt.title("Heatmap")
plt.show()

# %%
#low correlation b/w height, gender and calories => drop 

df_selected=df_cleaned.drop(columns=["Height","Gender"])

corr_matrix2=df_selected.corr() 
plt.figure(figsize=(8,6))
sb.heatmap(corr_matrix2,annot=True,cmap="coolwarm",fmt=".2f",linewidths=0.5) 
plt.title("Heatmap")
plt.show()

# %%
x=df_selected.iloc[:,:-1]
x
# Out:
#         Age     Weight  Duration  Heart_Rate  Body_Temp
# 0      68.0  42.769667      29.0       105.0       40.8
# 1      20.0  60.000000      14.0        94.0       40.3
# 2      69.0  79.000000       5.0        88.0       38.7
# 3      34.0  71.000000      13.0       100.0       40.5
# 4      27.0  58.000000      10.0        81.0       39.8
# ...     ...        ...       ...         ...        ...
# 14995  20.0  86.000000      11.0        92.0       40.4
# 14996  27.0  65.000000       6.0        85.0       39.2
# 14997  43.0  58.000000      16.0        90.0       40.1
# 14998  78.0  97.000000       2.0        84.0       38.3
# 14999  63.0  79.000000      18.0        92.0       40.5
#
# [14611 rows x 5 columns]

# %%
y=df_selected.iloc[:,-1]
y
# Out:
# 0        231.0
# 1         66.0
# 2         26.0
# 3         71.0
# 4         35.0
#          ...
# 14995     45.0
# 14996     23.0
# 14997     75.0
# 14998     11.0
# 14999     98.0
# Name: Calories, Length: 14611, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
#         Age  Weight  Duration  Heart_Rate  Body_Temp
# 4601   23.0    59.0       5.0        88.0       39.4
# 13004  49.0    97.0      22.0        93.0       40.9
# 8776   52.0    87.0       9.0        91.0       39.7
# 242    50.0    55.0      13.0       101.0       40.4
# 4329   72.0    89.0       5.0        79.0       39.0
# ...     ...     ...       ...         ...        ...
# 927    50.0    58.0      17.0        95.0       40.1
# 5330   21.0    99.0      15.0        99.0       40.1
# 12483  25.0    90.0      22.0       104.0       40.7
# 239    71.0    60.0      18.0        97.0       40.5
# 13701  26.0    61.0      13.0        97.0       40.3
#
# [10227 rows x 5 columns]

# %%
#model creation

from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 26.61332607,  10.14289573,  35.7586756 , ...,  46.2589972 ,
#        137.83537822,  69.05595189])

# %%
df2=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred,'Difference':y_test-y_pred})
df2
# Out:
#        Actual_value  Predicted_value  Difference
# 9077           22.0        26.613326   -4.613326
# 10725          17.0        10.142896    6.857104
# 13956          27.0        35.758676   -8.758676
# 9805           26.0        16.437948    9.562052
# 9655            5.0       -21.104924   26.104924
# ...             ...              ...         ...
# 7495           75.0        74.007029    0.992971
# 122           158.0       151.308759    6.691241
# 11536          47.0        46.258997    0.741003
# 9533          139.0       137.835378    1.164622
# 11738          57.0        69.055952  -12.055952
#
# [4384 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score

mape=mean_absolute_percentage_error(y_test,y_pred)
mape
# Out:
# 0.2435682118263066

# %%
sc=r2_score(y_test,y_pred)
sc
# Out:
# 0.965887080116932
