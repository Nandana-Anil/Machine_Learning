# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

df=pd.read_csv('Student_Performance.csv')
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df['Extracurricular Activities'].value_counts()
# Out:
# Extracurricular Activities
# No     5052
# Yes    4948
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

enc=LabelEncoder()

df['Extracurricular Activities']=enc.fit_transform(df['Extracurricular Activities'])
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
x=df.iloc[:,:-1]
x
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
plt.scatter(df['Hours Studied'],y,color='m')
plt.title('Hours_Studied vs Student Performance')
# Out:
# Text(0.5, 1.0, 'Hours_Studied vs Student Performance')

# %%
plt.scatter(df['Previous Scores'],y,color='m')
plt.title('Previous Scores vs Student Performance')
# Out:
# Text(0.5, 1.0, 'Previous Scores vs Student Performance')

# %%
plt.scatter(df['Extracurricular Activities'],y,color='m')
plt.title('Extracurricular Activities vs Student Performance')
# Out:
# Text(0.5, 1.0, 'Extracurricular Activities vs Student Performance')

# %%
plt.scatter(df['Sleep Hours'],y,color='m')
plt.title('Sleep Hours vs Student Performance')
# Out:
# Text(0.5, 1.0, 'Sleep Hours vs Student Performance')

# %%
plt.scatter(df['Sample Question Papers Practiced'],y,color='m')
plt.title('Sample Question Papers Practiced vs Student Performance')
# Out:
# Text(0.5, 1.0, 'Sample Question Papers Practiced vs Student Performance')

# %%
#plot regression line

import seaborn as sb
sb.regplot(x=df['Hours Studied'],y=y)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
sb.regplot(x=df['Previous Scores'],y=y,color='m')
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Performance Index'>

# %%
sb.regplot(x=df['Extracurricular Activities'],y=y,color='r')
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='Performance Index'>

# %%
sb.regplot(x=df['Sleep Hours'],y=y,color='y')
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Performance Index'>

# %%
sb.regplot(x=df['Sample Question Papers Practiced'],y=y,color='k')
# Out:
# <Axes: xlabel='Sample Question Papers Practiced', ylabel='Performance Index'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
#Model

from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
y_pred
# Out:
# array([54.74728554, 22.61884434, 47.93665124, ..., 33.42451751,
#        67.92578967, 31.20587077])

# %%
print('Slopes are: ',list(zip(x,model.coef_)))
# Out:
# Slopes are:  [('Hours Studied', 2.858952230523516), ('Previous Scores', 1.01551979428808), ('Extracurricular Activities', 0.5817128541736176), ('Sleep Hours', 0.47967675981703306), ('Sample Question Papers Practiced', 0.19039415655051095)]

# %%
print('Constant is: ',model.intercept_)
# Out:
# Constant is:  -33.83654380714167

# %%
df1=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred,'Difference':y_test-y_pred})
df1
# Out:
#       Actual_value  Predicted_value  Difference
# 6252          51.0        54.747286   -3.747286
# 4684          20.0        22.618844   -2.618844
# 1731          46.0        47.936651   -1.936651
# 4742          28.0        31.340099   -3.340099
# 4521          41.0        43.059743   -2.059743
# ...            ...              ...         ...
# 8014          32.0        31.819775    0.180225
# 1074          40.0        37.503045    2.496955
# 3063          33.0        33.424518   -0.424518
# 6487          69.0        67.925790    1.074210
# 4705          29.0        31.205871   -2.205871
#
# [3000 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score

mape=mean_absolute_percentage_error(y_test,y_pred)
mape
# Out:
# 0.03504200252156815

# %%
score=r2_score(y_test,y_pred)
score
# Out:
# 0.9890110607021136
